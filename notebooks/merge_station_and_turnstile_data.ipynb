# %%
from __future__ import print_function, division

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import datetime

# %%
# Source: http://web.mta.info/developers/turnstile.html
def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []

    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [190907, 190914, 190921]
turnstiles_df = get_data(week_nums)

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/31/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/31/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/31/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/31/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/31/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7183242
# 1  REGULAR  7183258
# 2  REGULAR  7183278
# 3  REGULAR  7183393
# 4  REGULAR  7183572
#
#    EXITS
# 0                                            2433142
# 1                                            2433149
# 2                                            2433176
# 3                                            2433262
# 4                                            2433312

# %%
# Out:
# 04:00:00    52087
# 08:00:00    52042
# 00:00:00    52036
# 05:00:00    38841
# 01:00:00    38834
# Name: TIME, dtype: int64
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/31/2019
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/31/2019
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/31/2019
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/01/2019
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/01/2019
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/01/2019
# 12       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/02/2019
# 13       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/02/2019
# 14       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/02/2019
# 18       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/03/2019
# ...

# %%
# Out:
# 16:00:00    52073
# 20:00:00    52031
# 21:00:00    38807
# 13:00:00    38804
# 17:00:00    38791
# Name: TIME, dtype: int64
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/31/2019
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/31/2019
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/01/2019
# 11       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/01/2019
# 16       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/02/2019
# 17       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/02/2019
# 22       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/03/2019
# 23       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/03/2019
# 28       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/04/2019
# 29       A002  R051  02-00-00          59 ST  NQR456W      BMT  09/04/2019
# ...

# %%
mta_stations_csv_path = '../data/mta_stations.csv'

mta_stations = pd.read_csv(mta_stations_csv_path, nrows=10)

mta_stations.rename(columns={'GTFS Stop ID': 'UNIT', 'Division': 'DIVISION'}, inplace=True)

mta_stations
# Out:
#    Station ID  Complex ID UNIT DIVISION                 Line  \
# 0           1           1  R01      BMT              Astoria
# 1           2           2  R03      BMT              Astoria
# 2           3           3  R04      BMT              Astoria
# 3           4           4  R05      BMT              Astoria
# 4           5           5  R06      BMT              Astoria
# 5           6           6  R08      BMT              Astoria
# 6           7         613  R11      BMT              Astoria
# 7           8           8  R13      BMT              Astoria
# 8           9           9  R14      BMT  Broadway - Brighton
# 9          10          10  R15      BMT  Broadway - Brighton
#
#                 Stop Name Borough Daytime Routes Structure  GTFS Latitude  \
# 0  Astoria - Ditmars Blvd       Q            N W  Elevated      40.775036
# 1            Astoria Blvd       Q            N W  Elevated      40.770258
# ...

# %%
df_with_borough = \
    pd.merge(turnstiles_df, mta_stations[[ 'UNIT', 'Borough' ]], on='UNIT', how='left')

turnstiles_df.head()

# new_df
# turnstiles_df[turnstiles_df['STATION'] == '59 ST']
# turnstiles_df['UNIT'].str.contains('R20').value_counts()

print(new_df)

# new_df[new_df['UNIT'] == 'R20']

# turnstiles_df

# mta_stations[['GTFS Stop ID', 'Borough']]

# new_df

# mta_stations[[ 'UNIT', 'Borough' ]].dtypes
